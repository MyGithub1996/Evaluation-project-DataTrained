# %%
#loading dataframe libraries
import pandas as pd
#loading algebra libraries
import numpy as np
#loading visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#loading warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('fraud_detection.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
#checking the shape of the data
df.shape
# Out:
# (1000, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %%
df.drop(["_c39"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %%
df=df.replace('?',np.NaN)

# %%
df=df.dropna()

# %%
df.head()
# Out:
#     months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                  328   48         521585       17-10-2014           OH
# 2                  134   29         687698       06-09-2000           OH
# 5                  256   39         104594       12-10-2006           OH
# 8                   27   33         485665       05-02-1997           IL
# 11                 447   61         214618       29-05-1999           OH
#
#    policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0     250/500               1000                1406.91               0
# 2     100/300               2000                1413.14         5000000
# 5     250/500               1000                1351.10               0
# 8     100/300                500                1442.99               0
# 11    100/300               2000                1137.16               0
#
#     insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0        466132  ...         2                     YES              71610
# 2        430632  ...         3                      NO              34650
# 5        478456  ...         2                      NO              64100
# 8        601734  ...         1                     YES              27700
# 11       615561  ...         2                     YES             114920
#
#    injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0          6510          13020          52080       Saab        92x      2004
# 2          7700           3850          23100      Dodge        RAM      2007
# 5          6410           6410          51280       Saab         95      2003
# 8          2770           2770          22160     Toyota      Camry      2012
# 11        17680          17680          79560       Audi         A3      2006
#
#    fraud_reported
# 0               Y
# 2               N
# 5               Y
# 8               N
# 11              N
#
# [5 rows x 39 columns]

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# dtype: object

# %%
#labelencoding 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['policy_bind_date']=le.fit_transform(df['policy_bind_date'])

# %%
df['policy_state']=le.fit_transform(df['policy_state'])

# %%
df['policy_csl']=le.fit_transform(df['policy_csl'])

# %%
df['insured_sex']=le.fit_transform(df['insured_sex'])

# %%
df['insured_education_level']=le.fit_transform(df['insured_education_level'])

# %%
df['insured_occupation']=le.fit_transform(df['insured_occupation'])

# %%
df['insured_hobbies']=le.fit_transform(df['insured_hobbies'])

# %%
df['insured_relationship']=le.fit_transform(df['insured_relationship'])

# %%
df['incident_date']=le.fit_transform(df['incident_date'])

# %%
df['incident_type']=le.fit_transform(df['incident_type'])

# %%
df['collision_type']=le.fit_transform(df['collision_type'])

# %%
df['incident_severity']=le.fit_transform(df['incident_severity'])

# %%
df['authorities_contacted']=le.fit_transform(df['authorities_contacted'])

# %%
df['incident_state']=le.fit_transform(df['incident_state'])

# %%
df['incident_city']=le.fit_transform(df['incident_city'])

# %%
df['incident_location']=le.fit_transform(df['incident_location'])

# %%
df['property_damage']=le.fit_transform(df['property_damage'])

# %%
df['police_report_available']=le.fit_transform(df['police_report_available'])

# %%
df['auto_make']=le.fit_transform(df['auto_make'])

# %%
df['auto_model']=le.fit_transform(df['auto_model'])

# %%
df['fraud_reported']=le.fit_transform(df['fraud_reported'])

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                 int32
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation               int32
# insured_hobbies                  int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_date                    int32
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# incident_location                int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                  int32
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available          int32
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                        int32
# auto_model                       int32
# auto_year                        int64
# fraud_reported                   int32
# dtype: object

# %%
df.head()
# Out:
#     months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                  328   48         521585               194             2
# 2                  134   29         687698                62             2
# 5                  256   39         104594               134             2
# 8                   27   33         485665                46             0
# 11                 447   61         214618               317             2
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0            1               1000                1406.91               0
# 2            0               2000                1413.14         5000000
# 5            1               1000                1351.10               0
# 8            0                500                1442.99               0
# 11           0               2000                1137.16               0
#
#     insured_zip  ...  witnesses  police_report_available  total_claim_amount  \
# 0        466132  ...          2                        1               71610
# 2        430632  ...          3                        0               34650
# 5        478456  ...          2                        0               64100
# 8        601734  ...          1                        1               27700
# 11       615561  ...          2                        1              114920
#
#     injury_claim  property_claim  vehicle_claim  auto_make  auto_model  \
# 0           6510           13020          52080         10           1
# 2           7700            3850          23100          4          30
# 5           6410            6410          51280         10           3
# 8           2770            2770          22160         12           9
# 11         17680           17680          79560          1           4
#
#     auto_year  fraud_reported
# 0        2004               1
# 2        2007               0
# 5        2003               1
# 8        2012               0
# 11       2006               0
#
# [5 rows x 39 columns]

# %%
df.describe()
# Out:
#        months_as_customer         age  policy_number  policy_bind_date  \
# count          340.000000  340.000000     340.000000        340.000000
# mean           211.623529   39.408824  554678.044118        168.226471
# std            112.779915    9.309204  266669.876966         97.461036
# min              1.000000   20.000000  100804.000000          0.000000
# 25%            123.750000   32.000000  337547.250000         83.750000
# 50%            204.500000   39.000000  533135.500000        168.500000
# 75%            289.000000   45.250000  794964.250000        252.250000
# max            479.000000   64.000000  996850.000000        335.000000
#
#        policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# count    340.000000  340.000000         340.000000             340.000000
# mean       1.079412    0.920588        1161.764706            1270.981529
# std        0.835877    0.803488         612.319304             245.008304
# min        0.000000    0.000000         500.000000             538.170000
# 25%        0.000000    0.000000         500.000000            1101.765000
# 50%        1.000000    1.000000        1000.000000            1274.665000
# 75%        2.000000    2.000000        2000.000000            1437.467500
# max        2.000000    2.000000        2000.000000            1969.630000
#
#        umbrella_limit    insured_zip  ...   witnesses  \
# count    3.400000e+02     340.000000  ...  340.000000
# mean     9.411765e+05  501608.923529  ...    1.464706
# std      2.099883e+06   71966.015133  ...    1.103195
# min      0.000000e+00  430232.000000  ...    0.000000
# 25%      0.000000e+00  447534.500000  ...    0.000000
# 50%      0.000000e+00  466207.500000  ...    2.000000
# 75%      0.000000e+00  603018.500000  ...    2.000000
# max      1.000000e+07  620869.000000  ...    3.000000
#
#        police_report_available  total_claim_amount  injury_claim  \
# count               340.000000          340.000000    340.000000
# mean                  0.452941        62868.235294   8886.205882
# std                   0.498514        16361.337381   4143.660334
# min                   0.000000        27700.000000      0.000000
# 25%                   0.000000        52157.500000   5747.500000
# 50%                   0.000000        61380.000000   7690.000000
# 75%                   1.000000        73810.000000  12105.000000
# max                   1.000000       114920.000000  21330.000000
#
#        property_claim  vehicle_claim   auto_make  auto_model    auto_year  \
# count      340.000000     340.000000  340.000000  340.000000   340.000000
# mean      8769.852941   45212.176471    6.235294   18.782353  2004.629412
# std       4003.652423   11470.884470    4.032748   11.378173     6.009654
# min          0.000000   19670.000000    0.000000    0.000000  1995.000000
# 25%       5857.500000   37152.500000    3.000000    8.750000  1999.000000
# 50%       7560.000000   44615.000000    6.000000   20.000000  2005.000000
# 75%      11510.000000   53860.000000   10.000000   29.000000  2010.000000
# max      21580.000000   79560.000000   13.000000   38.000000  2015.000000
#
#        fraud_reported
# count      340.000000
# mean         0.255882
# std          0.436999
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 39 columns]

# %%
corr=df.corr()

# %%
corr
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.948106       0.018708
# age                                    0.948106  1.000000       0.032417
# policy_number                          0.018708  0.032417       1.000000
# policy_bind_date                      -0.021057 -0.043647       0.061225
# policy_state                          -0.012292 -0.038303       0.057217
# policy_csl                            -0.041673 -0.064268       0.027664
# policy_deductable                      0.055476  0.053310      -0.024442
# policy_annual_premium                 -0.029872 -0.019726       0.081936
# umbrella_limit                        -0.076510 -0.090816      -0.026299
# insured_zip                           -0.039929 -0.044295       0.057287
# insured_sex                            0.055128  0.065191       0.042693
# insured_education_level               -0.067662 -0.056546      -0.023220
# insured_occupation                    -0.023693 -0.007949       0.009576
# insured_hobbies                       -0.113410 -0.074127       0.021736
# insured_relationship                   0.068373  0.075511       0.009178
# capital-gains                          0.007731 -0.025867      -0.029474
# capital-loss                           0.028531  0.018863      -0.070648
# incident_date                         -0.056181 -0.061858       0.037222
# incident_type                         -0.003004  0.003079       0.014955
# collision_type                        -0.119329 -0.133114      -0.024489
# incident_severity                     -0.048088 -0.051098      -0.030486
# authorities_contacted                 -0.027603 -0.032630       0.057048
# incident_state                         0.032287  0.016925      -0.039154
# incident_city                          0.034963  0.027913      -0.053430
# incident_location                      0.016485  0.027452       0.093469
# incident_hour_of_the_day               0.034657  0.064314      -0.054411
# number_of_vehicles_involved            0.001372 -0.000958      -0.023326
# property_damage                       -0.011244 -0.009648      -0.041029
# bodily_injuries                        0.003291 -0.020842       0.022052
# witnesses                              0.016726  0.020510       0.063691
# police_report_available               -0.087360 -0.065445       0.006378
# total_claim_amount                     0.102402  0.091621       0.023322
# injury_claim                           0.112963  0.112108      -0.005520
# property_claim                         0.059356  0.036183       0.051863
# vehicle_claim                          0.084537  0.077557       0.017157
# auto_make                              0.013900  0.019431      -0.005005
# auto_model                             0.012786  0.029416       0.075780
# auto_year                              0.010766  0.000396       0.095868
# fraud_reported                         0.005492 -0.030866      -0.001114
#
#                              policy_bind_date  policy_state  policy_csl  \
# months_as_customer                  -0.021057     -0.012292   -0.041673
# age                                 -0.043647     -0.038303   -0.064268
# policy_number                        0.061225      0.057217    0.027664
# policy_bind_date                     1.000000      0.052826    0.049238
# policy_state                         0.052826      1.000000   -0.030112
# policy_csl                           0.049238     -0.030112    1.000000
# policy_deductable                    0.031118      0.015171   -0.048760
# policy_annual_premium               -0.042764     -0.001229    0.001410
# umbrella_limit                      -0.055716      0.012753   -0.011518
# insured_zip                         -0.024069      0.037965   -0.087683
# insured_sex                          0.056664     -0.000166    0.051527
# insured_education_level              0.024846     -0.031020    0.038051
# insured_occupation                   0.075842      0.002069    0.044785
# insured_hobbies                      0.069682     -0.092857    0.011091
# insured_relationship                 0.015935     -0.045158   -0.046850
# capital-gains                       -0.033361      0.115829    0.062969
# capital-loss                        -0.032809     -0.031273   -0.052784
# incident_date                        0.012784      0.048744   -0.002977
# incident_type                        0.065214      0.050633    0.035332
# collision_type                       0.001380     -0.009635    0.042046
# incident_severity                   -0.087281     -0.062842    0.074487
# authorities_contacted               -0.080385     -0.025404    0.046389
# incident_state                       0.004651     -0.036001    0.030559
# incident_city                        0.106814     -0.048911    0.069014
# incident_location                    0.030074      0.041307   -0.055857
# incident_hour_of_the_day            -0.034460      0.048157    0.080503
# number_of_vehicles_involved         -0.097846     -0.066487   -0.042386
# property_damage                      0.027370     -0.055490   -0.023013
# bodily_injuries                     -0.034650      0.019643   -0.033988
# witnesses                           -0.103290      0.081422    0.101657
# police_report_available              0.089197     -0.079495    0.023783
# total_claim_amount                   0.084555     -0.055309    0.065545
# injury_claim                         0.057379     -0.079485   -0.046331
# property_claim                       0.084046      0.007478    0.085487
# vehicle_claim                        0.070542     -0.052787    0.080388
# auto_make                            0.059344     -0.081693   -0.040646
# auto_model                          -0.042605      0.055480    0.002944
# auto_year                            0.027506     -0.051673    0.069028
# fraud_reported                       0.044486      0.121871    0.049641
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.055476              -0.029872
# age                                   0.053310              -0.019726
# policy_number                        -0.024442               0.081936
# policy_bind_date                      0.031118              -0.042764
# policy_state                          0.015171              -0.001229
# policy_csl                           -0.048760               0.001410
# policy_deductable                     1.000000              -0.039364
# policy_annual_premium                -0.039364               1.000000
# umbrella_limit                       -0.039608              -0.024684
# insured_zip                           0.008463               0.105388
# insured_sex                          -0.101365               0.025849
# insured_education_level              -0.012791              -0.079682
# insured_occupation                    0.011455               0.050769
# insured_hobbies                       0.012054               0.009756
# insured_relationship                 -0.101394              -0.054702
# capital-gains                         0.103114              -0.034156
# capital-loss                         -0.057373               0.002928
# incident_date                         0.003060               0.093507
# incident_type                        -0.083215              -0.016847
# collision_type                       -0.116614              -0.014466
# incident_severity                     0.007473              -0.094286
# authorities_contacted                 0.013674              -0.124196
# incident_state                        0.068739               0.006740
# incident_city                        -0.109928               0.043740
# incident_location                    -0.063127               0.020224
# incident_hour_of_the_day              0.004418               0.040495
# number_of_vehicles_involved           0.086107               0.002053
# property_damage                       0.026912               0.060595
# bodily_injuries                      -0.079852               0.073005
# witnesses                             0.065246              -0.031110
# police_report_available               0.034676               0.036351
# total_claim_amount                    0.125091               0.016437
# injury_claim                          0.092107              -0.066527
# property_claim                        0.173811               0.025526
# vehicle_claim                         0.084485               0.038567
# auto_make                            -0.011876               0.031316
# auto_model                           -0.020336              -0.040416
# auto_year                             0.056020              -0.003328
# fraud_reported                        0.004701               0.130862
#
#                              umbrella_limit  insured_zip  ...  witnesses  \
# months_as_customer                -0.076510    -0.039929  ...   0.016726
# age                               -0.090816    -0.044295  ...   0.020510
# policy_number                     -0.026299     0.057287  ...   0.063691
# policy_bind_date                  -0.055716    -0.024069  ...  -0.103290
# policy_state                       0.012753     0.037965  ...   0.081422
# policy_csl                        -0.011518    -0.087683  ...   0.101657
# policy_deductable                 -0.039608     0.008463  ...   0.065246
# policy_annual_premium             -0.024684     0.105388  ...  -0.031110
# umbrella_limit                     1.000000     0.006366  ...   0.005468
# insured_zip                        0.006366     1.000000  ...  -0.009243
# insured_sex                        0.108488    -0.019690  ...   0.052301
# insured_education_level           -0.075726    -0.061579  ...   0.050210
# insured_occupation                 0.044309    -0.069649  ...  -0.044378
# insured_hobbies                    0.069155     0.017547  ...  -0.112754
# insured_relationship               0.040126    -0.017920  ...  -0.013929
# capital-gains                     -0.062238    -0.005903  ...   0.028986
# capital-loss                      -0.024852     0.013012  ...   0.001486
# incident_date                      0.026953     0.064006  ...  -0.003037
# incident_type                      0.003466     0.050727  ...  -0.036636
# collision_type                     0.024300    -0.018235  ...  -0.056543
# incident_severity                 -0.013946     0.071166  ...  -0.046121
# authorities_contacted             -0.048896    -0.049705  ...   0.112070
# incident_state                     0.030837    -0.078534  ...  -0.026159
# incident_city                      0.053091    -0.044430  ...   0.038186
# incident_location                 -0.021323    -0.000692  ...  -0.043716
# incident_hour_of_the_day          -0.022385     0.085926  ...   0.003528
# number_of_vehicles_involved        0.011848    -0.024515  ...   0.017594
# property_damage                   -0.085577    -0.054000  ...   0.014528
# bodily_injuries                    0.126795     0.053741  ...  -0.035496
# witnesses                          0.005468    -0.009243  ...   1.000000
# police_report_available           -0.044921     0.017417  ...   0.013062
# total_claim_amount                -0.057825    -0.027500  ...   0.007483
# injury_claim                      -0.052027    -0.046013  ...  -0.050953
# property_claim                    -0.005201    -0.017762  ...   0.149398
# vehicle_claim                     -0.061868    -0.016403  ...  -0.023064
# auto_make                         -0.026576     0.016718  ...   0.019775
# auto_model                         0.086997     0.077136  ...  -0.025994
# auto_year                         -0.036328    -0.113919  ...   0.090123
# fraud_reported                     0.106459    -0.039639  ...   0.034085
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                         -0.087360            0.102402
# age                                        -0.065445            0.091621
# policy_number                               0.006378            0.023322
# policy_bind_date                            0.089197            0.084555
# policy_state                               -0.079495           -0.055309
# policy_csl                                  0.023783            0.065545
# policy_deductable                           0.034676            0.125091
# policy_annual_premium                       0.036351            0.016437
# umbrella_limit                             -0.044921           -0.057825
# insured_zip                                 0.017417           -0.027500
# insured_sex                                -0.026988            0.010599
# insured_education_level                     0.068436            0.066721
# insured_occupation                          0.000829            0.028556
# insured_hobbies                            -0.006727            0.070550
# insured_relationship                        0.005793           -0.063432
# capital-gains                               0.034751           -0.050386
# capital-loss                               -0.107347           -0.080931
# incident_date                               0.004215            0.017082
# incident_type                               0.025866            0.089494
# collision_type                              0.097370           -0.139204
# incident_severity                          -0.019826           -0.033691
# authorities_contacted                       0.054534            0.050293
# incident_state                              0.063085            0.056292
# incident_city                               0.047409            0.085979
# incident_location                           0.024080            0.025807
# incident_hour_of_the_day                    0.008502           -0.049847
# number_of_vehicles_involved                -0.028622           -0.103877
# property_damage                            -0.004454            0.065602
# bodily_injuries                            -0.027069            0.088891
# witnesses                                   0.013062            0.007483
# police_report_available                     1.000000            0.124203
# total_claim_amount                          0.124203            1.000000
# injury_claim                                0.121875            0.693511
# property_claim                              0.030701            0.642391
# vehicle_claim                               0.122414            0.951605
# auto_make                                   0.080357           -0.004820
# auto_model                                  0.068397            0.019096
# auto_year                                   0.054224            0.033648
# fraud_reported                             -0.019037            0.061075
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer               0.112963        0.059356       0.084537
# age                              0.112108        0.036183       0.077557
# policy_number                   -0.005520        0.051863       0.017157
# policy_bind_date                 0.057379        0.084046       0.070542
# policy_state                    -0.079485        0.007478      -0.052787
# policy_csl                      -0.046331        0.085487       0.080388
# policy_deductable                0.092107        0.173811       0.084485
# policy_annual_premium           -0.066527        0.025526       0.038567
# umbrella_limit                  -0.052027       -0.005201      -0.061868
# insured_zip                     -0.046013       -0.017762      -0.016403
# insured_sex                     -0.024138        0.004924       0.022119
# insured_education_level          0.050623        0.066984       0.053501
# insured_occupation               0.061269       -0.023563       0.026822
# insured_hobbies                  0.119472        0.010318       0.053870
# insured_relationship             0.028715       -0.094253      -0.067951
# capital-gains                   -0.011849       -0.002378      -0.066757
# capital-loss                    -0.008395       -0.064255      -0.089976
# incident_date                    0.011627        0.051154       0.002311
# incident_type                    0.018331        0.043324       0.105906
# collision_type                  -0.081044       -0.111700      -0.130289
# incident_severity               -0.027655       -0.037639      -0.024928
# authorities_contacted           -0.011819        0.103815       0.039769
# incident_state                   0.030883        0.054530       0.050103
# incident_city                    0.002141        0.164936       0.064294
# incident_location                0.053689        0.019511       0.010605
# incident_hour_of_the_day        -0.031690       -0.076384      -0.032991
# number_of_vehicles_involved     -0.037778       -0.049680      -0.117178
# property_damage                  0.067982        0.011746       0.064913
# bodily_injuries                  0.026921        0.114026       0.077266
# witnesses                       -0.050953        0.149398      -0.023064
# police_report_available          0.121875        0.030701       0.122414
# total_claim_amount               0.693511        0.642391       0.951605
# injury_claim                     1.000000        0.267716       0.534506
# property_claim                   0.267716        1.000000       0.470530
# vehicle_claim                    0.534506        0.470530       1.000000
# auto_make                        0.019293        0.039711      -0.027704
# auto_model                      -0.020720        0.049454       0.017461
# auto_year                        0.029617        0.091076       0.005507
# fraud_reported                  -0.010410        0.048427       0.073971
#
#                              auto_make  auto_model  auto_year  fraud_reported
# months_as_customer            0.013900    0.012786   0.010766        0.005492
# age                           0.019431    0.029416   0.000396       -0.030866
# policy_number                -0.005005    0.075780   0.095868       -0.001114
# policy_bind_date              0.059344   -0.042605   0.027506        0.044486
# policy_state                 -0.081693    0.055480  -0.051673        0.121871
# policy_csl                   -0.040646    0.002944   0.069028        0.049641
# policy_deductable            -0.011876   -0.020336   0.056020        0.004701
# policy_annual_premium         0.031316   -0.040416  -0.003328        0.130862
# umbrella_limit               -0.026576    0.086997  -0.036328        0.106459
# insured_zip                   0.016718    0.077136  -0.113919       -0.039639
# insured_sex                   0.032759   -0.045231  -0.056129        0.027454
# insured_education_level       0.103592   -0.002750   0.091756       -0.041202
# insured_occupation            0.011498    0.118747   0.022529        0.096229
# insured_hobbies               0.027502    0.008521  -0.051581       -0.045172
# insured_relationship         -0.059229    0.068280  -0.021743        0.053336
# capital-gains                 0.056638    0.093309   0.042711       -0.030227
# capital-loss                 -0.080152   -0.012594  -0.051097       -0.015628
# incident_date                 0.094009   -0.045509   0.047442        0.006805
# incident_type                -0.023293   -0.030105  -0.026001        0.060362
# collision_type                0.073345    0.026898   0.030923       -0.065928
# incident_severity             0.001815   -0.000097   0.056220       -0.472013
# authorities_contacted        -0.034038    0.080691   0.099368       -0.016569
# incident_state                0.039810   -0.030396  -0.007507       -0.079299
# incident_city                 0.036803    0.099565   0.014698       -0.038846
# incident_location            -0.030012    0.023105  -0.019605       -0.038904
# incident_hour_of_the_day      0.011240   -0.053693  -0.010898        0.054110
# number_of_vehicles_involved   0.016996    0.019587   0.001053       -0.041587
# property_damage               0.024689   -0.040813   0.010829        0.088356
# bodily_injuries              -0.002171    0.051777   0.024295        0.045391
# witnesses                     0.019775   -0.025994   0.090123        0.034085
# police_report_available       0.080357    0.068397   0.054224       -0.019037
# total_claim_amount           -0.004820    0.019096   0.033648        0.061075
# injury_claim                  0.019293   -0.020720   0.029617       -0.010410
# property_claim                0.039711    0.049454   0.091076        0.048427
# vehicle_claim                -0.027704    0.017461   0.005507        0.073971
# auto_make                     1.000000   -0.224916   0.072257       -0.042634
# auto_model                   -0.224916    1.000000  -0.012399       -0.014277
# auto_year                     0.072257   -0.012399   1.000000       -0.004222
# fraud_reported               -0.042634   -0.014277  -0.004222        1.000000
#
# [39 rows x 39 columns]

# %%
plt.figure(figsize=(20,18))
sns.heatmap(corr,annot=True,fmt='0%',cbar='cool')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
df.drop('fraud_reported',axis=1).corrwith(df['fraud_reported']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title('Corelation with target variable')
plt.show()

# %%
plt.subplots(figsize=(8,5))
sns.countplot(x="policy_state",data=df)
plt.title("Policy state of the insurance")
plt.show()

# %%
plt.subplots(figsize=(8,5))
sns.countplot(x="policy_csl",data=df)
plt.title("Policy csl of the insurance")
plt.show()

# %%
plt.subplots(figsize=(8,5))
sns.countplot(x="witnesses",data=df)
plt.title("Witnesses of the insurance")
plt.show()

# %%
plt.subplots(figsize=(8,5))
sns.countplot(x="police_report_available",data=df)
plt.title("police reports")
plt.show()

# %%
plt.subplots(figsize=(8,5))
sns.countplot(x="fraud_reported",data=df)
plt.title("Fraud reported")
plt.show()

# %%
#checking skewness
for col in df.describe().columns:
    sns.distplot(df[col],color='r')
    plt.show()

# %%
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<0.55:
            df[col]=np.cbrt(df[col])

# %% [markdown]
# ### Model Training

# %%
#Feature selection
x=df.drop('fraud_reported',axis=1)
y=df['fraud_reported']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42,stratify=y)

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrd=rf.predict(x_test)
print(confusion_matrix(y_test,predrd))
print(accuracy_score(y_test,predrd))
print(classification_report(y_test,predrd))
# Out:
# [[72  4]
#  [18  8]]
# 0.7843137254901961
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.95      0.87        76
#          1.0       0.67      0.31      0.42        26
#
#     accuracy                           0.78       102
#    macro avg       0.73      0.63      0.64       102
# weighted avg       0.77      0.78      0.75       102

# %%
#hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators=[int(x) for x in np.linspace(start=40,stop=150,num=15)]
max_depth=[int(x) for x in np.linspace(40,150,num=15)]

# %%
param_dist={'n_estimators':n_estimators,'max_depth':max_depth}

# %%
rf_tuned=RandomForestClassifier(random_state=42)

# %%
rf_cv=RandomizedSearchCV(estimator=rf_tuned,param_distributions=param_dist,cv=5,random_state=42)

# %%
rf_cv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'max_depth': [40, 47, 55, 63, 71, 79,
#                                                       87, 95, 102, 110, 118,
#                                                       126, 134, 142, 150],
#                                         'n_estimators': [40, 47, 55, 63, 71, 79,
#                                                          87, 95, 102, 110, 118,
#                                                          126, 134, 142, 150]},
#                    random_state=42)

# %%
rf_cv.best_score_
# Out:
# 0.7688829787234042

# %%
rf_cv.best_params_
# Out:
# {'n_estimators': 142, 'max_depth': 110}

# %%
rf_best=RandomForestClassifier(max_depth=110,n_estimators=142,random_state=42)

# %%
rf_best.fit(x_train,y_train)
predy=rf_best.predict(x_test)
print(accuracy_score(y_test,predy))
print(confusion_matrix(y_test,predy))
print(classification_report(y_test,predy))
# Out:
# 0.7843137254901961
# [[73  3]
#  [19  7]]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.96      0.87        76
#          1.0       0.70      0.27      0.39        26
#
#     accuracy                           0.78       102
#    macro avg       0.75      0.61      0.63       102
# weighted avg       0.77      0.78      0.75       102

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,predy)

# %%
plt.style.use('default')
sns.heatmap(cm,annot=True,fmt='d',cmap='cool')
plt.savefig('heatmap.png')
plt.show()

# %%
import pickle
filename="Insurance_Fraud_Detection.pkl"
pickle.dump(rf_best,open(filename,"wb"))
